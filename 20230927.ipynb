# %%
import numpy as np
import numpy.random as rng
import matplotlib.pyplot as plt

# generating two random arrays
x_data = np.linspace(0, 100, 100)
y_data = x_data * 2 + rng.normal(0, 10, 100)

# plot the data
plt.plot(x_data, y_data)
plt.title('Random Data Plotting')
plt.show()

# %% [markdown]
# This is my lecture 0 code for Ph 20. I created 2 random numpy arrays and plotted them.
